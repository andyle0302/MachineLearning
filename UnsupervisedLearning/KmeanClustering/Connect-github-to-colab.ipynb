# %%
# %cd '/content/drive/MyDrive/MachineLearning'
# Out:
# /content/drive/MyDrive/MachineLearning
# Cloning into 'MachineLearning'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.

# %%
# !git remote set-url origin https://{'qtuter1997'}:{'Nh0cNh0911'}@github.com/{'qtuter1997'}/MachineLearning.git

# %%
# %cd '/content/drive/MyDrive/MachineLearning/MachineLearning'
# !git config --global user.email "nh0k.0k.911@gmail.com"
# !git config --global user.name "qtuter1997"
# Out:
# /content/drive/MyDrive/MachineLearning/MachineLearning

# %%
# !git commit -m 'Create folder and use cases'
# !git push
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
# 	gray.jpg
# 	jordan.jpg
#
# nothing added to commit but untracked files present
# Everything up-to-date

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
#
# 	SupervisedLearning/
# 	gray.jpg
# 	jordan.jpg
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add .
# !git commit -m 'Create folder and use cases'
# !git push
# Out:
# [main ce31aea] Create folder and use cases
#  2 files changed, 0 insertions(+), 0 deletions(-)
#  rename gray.jpg => Data/gray.jpg (100%)
#  rename jordan.jpg => Data/jordan.jpg (100%)
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 343 bytes | 171.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/qtuter1997/MachineLearning.git
#    b342679..ce31aea  main -> main
